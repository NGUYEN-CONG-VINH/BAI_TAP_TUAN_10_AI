# %% [markdown]
# <a href="https://colab.research.google.com/github/NGUYEN-CONG-VINH/BAI_TAP_TUAN_10_AI/blob/main/cifar100_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Nguyễn Công Vinh 20146183
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from keras.models import load_model
model100=load_model('/content/drive/MyDrive/colab/model1.h5')

# %%
import matplotlib.pyplot as plt
from keras.utils import load_img, img_to_array
img = load_img('/content/drive/MyDrive/colab/hinh/A1.jpg')
plt.imshow(img)
plt.show()

# %%
img=load_img('/content/drive/MyDrive/colab/hinh/A1.jpg',target_size=(32,32))
plt.imshow(img)
plt.show()

# %%
import numpy as np
img=img_to_array(img)
img=img.reshape(1,32*32*3)
img=img.astype('float32')/255
np.argmax(model100.predict(img),axis=-1)
# Out:
# 1/1 [==============================] - 0s 28ms/step
# array([50])

# %%
from matplotlib.image import imread
folder='/content/drive/MyDrive/colab/hinh'
for i in range(1,5):
  plt.subplot(5,5,i+1)
  filename=folder+'/'+'A'+str(i)+".jpg"
  img=imread(filename)
  plt.imshow(img)
plt.show()
